# %% [markdown]
# 📊 Comparação de Arquivos Excel Usando Coluna SELB <br>
#
# Versão 1 📌
#
# Este repositório contém um código Python que realiza a comparação entre dois arquivos Excel utilizando uma coluna comum chamada SELB.<br><br>
#
#
# 🎯 Objetivo<br>
#
# O objetivo deste código é identificar e listar:<br><br>
#
# 🔄 Valores da coluna SELB que estão presentes em ambos os arquivos.<br>
#
# 🔍 Valores da coluna SELB que estão presentes apenas em um dos arquivos.<br>
# Além disso, o programa gera um novo arquivo Excel unificado com as seguintes colunas:<br><br>
#
# 📝 SELB: Contendo todos os valores da coluna SELB encontrados em ambos os arquivos.<br><br>
#
# 🗒️ Observação: Indicando se cada valor da coluna SELB está presente em ambos os arquivos com "em conformidade" ou apenas em um dos arquivos com "não está em conformidade".<br><br>
#
# ✅ Critérios para a Coluna Observação<br>
#
# "Em conformidade": Se o valor da coluna SELB estiver presente em ambos os arquivos.<br>
# "Não está em conformidade": Se o valor da coluna SELB estiver presente apenas em um dos arquivos.<br>

# %%
import pandas as pd

# Load the two Excel files
file1 = pd.read_excel('perus.xlsx')
file2 = pd.read_excel('perus1.xlsx')

# Merge the two files on the SELB column
merged = pd.merge(file1, file2, on='SELB', how='outer', indicator=True)

# Identify values present in both files
common_values = merged[merged['_merge'] == 'both']['SELB'].unique()

# Identify values present only in one file
only_in_file1 = merged[merged['_merge'] == 'left_only']['SELB'].unique()
only_in_file2 = merged[merged['_merge'] == 'right_only']['SELB'].unique()

# Create a new Excel file with the unified columns
unified = pd.DataFrame({
    'SELB': pd.concat([file1['SELB'], file2['SELB']]).unique(),
    'Observação': ['em conformidade' if value in common_values else 'não está em conformidade' for value in pd.concat([file1['SELB'], file2['SELB']]).unique()]
})

# Save the unified file to a new Excel file
unified.to_excel('unified.xlsx', index=False)

print("Valores da coluna SELB presentes em ambos os arquivos:")
print(common_values)

print("\nValores da coluna SELB presentes apenas em um dos arquivos:")
print("Apenas em file1:", only_in_file1)
print("Apenas em file2:", only_in_file2)
# Out:
# Valores da coluna SELB presentes em ambos os arquivos:
# [1120 '10HX' '113X' '12JI' '12MF' '13GV' '13JI' '14YX' '15MF' '16GV'
#  '176U' '177T' '17BR' '17GV' '17JI' '18FQ' '18GL' '19GS' '200Z' '201Z'
#  '202Z' '204Z' '205Z' '206O' '206Z' '207Z' '208Z' '209Z' '20JI' '211Z'
#  '212N' '212Z' '213Z' '215Z' '216N' '216Z' '217Z' '218Z' '219Z' '21GA'
#  '21GB' '21GV' '220Z' '221Z' '222Z' '22GV' '22QD' '233Z' '234Z' '235Z'
#  '236Z' '237Z' '238Z' '23GS' '23RT' '240Z' '241Z' '242Z' '243Z' '246Z'
#  '247Z' '248Z' '249Z' '24HK' '250Z' '252R' '254Z' '255Z' '258R' '258Z'
#  '259Z' '25CR' '260R' '260Z' '261Z' '265N' '265Z' '266Z' '267Z' '269Z'
#  '26GC' '270Z' '271Z' '272Z' '275Z' '277Z' '278Z' '283Z' '284Z' '285Z'
#  '286Z' '287Z' '289Z' '28GV' '290Z' '291Z' '292Z' '298N' '300W' '30HD'
#  '320X' '34QD' '35QD' '36GV' '393I' '39IJ' '423N' '42GV' '434Q' '43GC'
#  '459Y' '45DP' '45DT' '45MR' '46BA' '46IJ' '473R' '479T' '481I' '485I'
#  '501X' '509X' '51JE' '52AO' '52JE' '54GB' '54MG' '565X' '568X ' '56JE'
#  '56LR' '57MA' '587X' '58HX' '58JE' '591H' '595Y' '59JE' '59NT' '59QY'
#  '60HX' '60JE' '60MF' '60MG' '62KP' '62QY' '634Y' '635Y ' '636Y' '673R'
#  '680R' '684W' '689W' '689X' '68DP' '68IJ' '697O' '69IJ' '70MF' '71HB'
#  '724W' '724Z' '726O' '728Z' '72IJ' '73HB' '75AH' '764W' '76AH' '76DU'
#  '76GF' '774W' '775W' '77AH' '781T' '81JE' '824W' '82ZV' '832P' '83JE'
#  '83MF' '840W' '851W' '853W' '85FJ' '85ME' '861W' '873W' '885T' '885W'
#  '88BJ' '88HX' '891T' '89HX' '89PY' '90DM' '91HX' '91NZ' '945O' '946O'
#  '94NZ' '954W' '95JE' '960W' '96HX' '985K' '98HY' '99JE' 'AGO3' 'ATM5'
#  'BGH7' 'BR25' 'BSF6' 'BSI2' 'BSJ3' 'BSL9' 'BTG3' 'BTG6' 'BTS1' 'BW19'
#  'CC57' 'CEN2' 'CP73' 'DA64' 'DGZ5' 'DH97' 'DIR3 ' 'DJM1' 'DJN7' 'DJP7'
#  'DLE6' 'DRN1' 'DRY4' 'DUG9' 'DYE8' 'DYR3' 'EGI1' 'EMC7' 'EPL5' 'ESD3'
#  'ESR1' 'ESU4' 'F049' 'FY72' 'GBN8' 'GH49' 'GJ11' 'GM35' 'GM39' 'GM43'
#  'GM89' 'GM90' 'GM91' 'GM92' 'GP68' 'GP90' 'GP94' 'GPC9' 'GPG8' 'GPS1'
#  'GQ27' 'GQ34' 'GQ35' 'GQ36' 'GQ38' 'GQ39' 'GQ42' 'GR36' 'GSL2' 'GX72'
#  'GY36' 'HBD9' 'HBE1' 'HBL1' 'HBL5' 'HBL7' 'HBL9' 'HD30' 'HDZ7' 'HEA3'
#  'HEA6' 'HEA9' 'HF12' 'HF33' 'HI61' 'HT10' 'HW77' 'HW84' 'HWI3' 'HWI4'
#  'HWI7' 'I943' 'IFK4' 'KHU8' 'KHU9' 'KPK2' 'KPL1' 'KSF1' 'KSI2' 'KWL4'
#  'KWM9' 'KWN1' 'KWR9' 'LDG8' 'LDI2' 'LHX7' 'LV39' 'LV68' 'MCH9' 'MCI1'
#  'MCI2' 'MCI7' 'MCI8' 'MCJ1' 'MCJ2' 'MCJ3' 'MCJ4' 'MCJ5' 'MCJ6' 'MCJ7'
#  'MCJ8' 'MCJ9' 'MCK1' 'MCK3' 'MCK4' 'MCK5' 'MCK6' 'MCK7' 'MCK8' 'MCK9'
#  'MCL1' 'MCL2' 'MCL3' 'MCL4' 'MCL5' 'MCL6' 'MCL7' 'MCL8' 'MCL9' 'MCM1'
#  'MCM2' 'MCM3' 'MCM4' 'MCM5' 'MCM6' 'MCM7' 'MCM8' 'MCM9' 'MCN1' 'MCN2'
#  'MCN3' 'MCN4' 'MCN5' 'MCN6' 'MCN7' 'MCN8' 'MCN9' 'MCO1' 'MCO2' 'MCO3'
#  'MCO4' 'MCO5' 'MCO6' 'MCO7' 'MCO8' 'MCO9' 'MCP1' 'MCP3' 'MCP4' 'MCP5'
#  'MCP6' 'MCP7' 'MCP8' 'MCP9' 'MCQ1' 'MCQ2' 'MCQ5' 'MCQ6' 'MCQ7' 'MCQ8'
#  'MCQ9' 'MCR1' 'MCR2' 'MCR3' 'MCR4' 'MCR5' 'MCR6' 'MCR7' 'MCR8' 'MCR9'
#  'MCS1' 'MCS2' 'MCS3' 'MCS4' 'MCU3' 'MCU4' 'MCU5' 'MCU6' 'MCU7' 'MCU8'
#  'MCU9' 'MCV1' 'MCV2' 'MCV3' 'MCV4' 'MCV5' 'MCV6' 'MCV7' 'MCV8' 'MCV9'
#  'MCW1' 'MCW2' 'MCW3' 'MCW4' 'MCW6' 'MCW7' 'MCW8' 'MCW9' 'MCX1' 'MCX2'
#  'MCX3' 'MCX4' 'MCX5' 'MCX6' 'MCY5' 'MCY6' 'MCY9' 'MJP4' 'MJP5' 'MJP6'
#  'MJP7' 'MJP8' 'MJQ2' 'MJQ4' 'MJS7' 'MJS8' 'MJS9' 'MJT1' 'MJT2' 'MJT3'
#  'MJT4' 'MJT5' 'MJT6' 'MJT7' 'MJT8' 'MJT9' 'MJU2' 'MJU3' 'MJU4' 'MJU5'
#  'MJU6' 'MJU7' 'MJU8' 'MQA4' 'MQA5' 'MQA6' 'MQA7' 'MQA8' 'MQD2' 'MQD3'
#  'MQD4' 'MQD5' 'MQD6' 'MQD7' 'MQD8' 'MQD9' 'MQE1' 'MQE2' 'MQE3' 'MQE4'
#  'MQE5' 'MQE6' 'MQE7' 'MQE8' 'MQE9' 'MQJ9' 'MQK1' 'MQK2' 'MQK3' 'MQK4'
#  'MQK5' 'MQL1' 'MQL2' 'MULTI' 'NH42' 'NM74' 'NM76' 'NN74' 'NO47' 'NO48'
#  'NO55' 'NQ01' 'NV03' 'OAB8' 'OAB9' 'OAC1' 'OAC9' 'OAD1' 'OAD2' 'OAG5'
#  'OAG6' 'OAG7' 'OAG8' 'OAG9' 'OE01' 'OF70' 'OF92' 'OH09' 'OHP1' 'OHP2'
#  'OHP3' 'OHP4' 'OHP5' 'OHP6' 'OHP7' 'OHP8' 'OHP9' 'OHQ1' 'OHQ2' 'OHR6'
#  'OHR7' 'OHR8' 'OHR9' 'OHS1' 'OHS2' 'OHS3' 'OHS4' 'OHS5' 'OHS6' 'OHS7'
#  'OHS8' 'OHU9' 'OHV8' 'OHV9' 'OHW1' 'OHW2' 'OHW5' 'OHW6' 'OHW7' 'OHW8'
#  'OHX2' 'OHX3' 'OHX4' 'OHX5' 'OHX7' 'OHX8' 'OHX9' 'OHY1' 'OHY2' 'OIC6'
#  'OIE2' 'OIE3' 'OIE4' 'OIE5' 'OIE8' 'OIE9' 'OIF1' 'OIF2' 'OIF4' 'OIF5'
#  'OIF6' 'OIF7' 'OIF8' 'OIG1' 'OIG2' 'OIG3' 'OIG4' 'OIG5' 'OIH2' 'OIH9'
#  'OII1' 'OII2' 'OII3' 'OII4' 'OII5' 'OII6' 'OII7' 'OII8' 'OII9' 'OIJ1'
#  'OIJ2' 'OJ08' 'OJ10' 'OJ34' 'OKV1' 'OKV2' 'OKV7' 'OKV8' 'OKW4' 'OKX1'
#  'OKX2' 'ON61' 'ON73' 'OO36' 'OO38' 'OO40' 'OO54' 'OO85' 'OQ52' 'OX80'
#  'PA08' 'PA14' 'PA32' 'PCO3' 'PE59' 'PG79' 'PL38' 'PQ94' 'RI34' 'RI38'
#  'RI78' 'RJ57' 'RK27' 'RK55' 'RN49' 'RN82' 'RN84' 'RO08' 'RO53' 'RO80'
#  'RP58' 'RU07' 'RU91' 'RX17' 'RX18' 'RX33' 'RX38' 'RX83' 'RY05' 'SAP9'
#  'SAR7' 'SH89' 'SI98' 'SJ16' 'SJ34' 'SJ99' 'SL05' 'SN18' 'SP21' 'SQW3'
#  'SSA1' 'TC52' 'TF86' 'TO23' 'TS92' 'TTS8' 'UG83' 'VE01' 'VL20' 'WJ32'
#  'WL18' 'WL19' 'WN73' 'WT39' 'WT41' 'WT45' 'WT49' 'WT50' 'XJ62' 'YD77'
#  'YE54' 'YE71' 'YG93' 'YG95' 'YK35' 'YN99' 'YP51' 'YQ33' 'YQ38' 'YS65'
#  'ZG78' nan]
#
# Valores da coluna SELB presentes apenas em um dos arquivos:
# Apenas em file1: [2500 2900 'MJ00' 'mcW5']
# Apenas em file2: ['256Z' '293Z' 'MCW5' 'MJU1']

# %% [markdown]
# Versão 2 📌

# %%
import pandas as pd

# Load the two Excel files
file1 = pd.read_excel('tablet05/tablet.xlsx')
file2 = pd.read_excel('tablet05/tablet2.xlsx')

# Merge the two files on the SELB column
merged = pd.merge(file1, file2, on='SELB', how='outer', indicator=True)

# Identify values present in both files
common_values = merged[merged['_merge'] == 'both']['SELB'].unique()

# Identify values present only in one file
only_in_file1 = merged[merged['_merge'] == 'left_only']['SELB'].unique()
only_in_file2 = merged[merged['_merge'] == 'right_only']['SELB'].unique()

# Create a new Excel file with the unified columns
unified = pd.DataFrame({
    'SELB': merged['SELB'],
    'Observação': ['em conformidade' if value in common_values else 'não está em conformidade' for value in merged['SELB']]
})

# Add the other columns from both files to the unified dataframe
unified = pd.concat([unified, merged.drop(['SELB', '_merge'], axis=1)], axis=1)

# Save the unified file to a new Excel file
unified.to_excel('tablet05/unified.xlsx', index=False)

print("Valores da coluna SELB presentes em ambos os arquivos:")
print(common_values)

print("\nValores da coluna SELB presentes apenas em um dos arquivos:")
print("Apenas em file1:", only_in_file1)
print("Apenas em file2:", only_in_file2)

unified1 = pd.DataFrame(only_in_file1)
unified1.to_excel('tablet05/only_in_file1.xlsx', index=False)

unified2 = pd.DataFrame(only_in_file2)
unified2.to_excel('tablet05/only_in_file2.xlsx', index=False)
# Out:
# Valores da coluna SELB presentes em ambos os arquivos:
# ['10ZA' '10ZB' '10ZD' '10ZT' '10ZV' '11ZA' '11ZB' '12ZA' '12ZB' '12ZV'
#  '13XO' '13ZA' '13ZB' '13ZV' '14XD' '14ZB' '14ZV' '15XD' '15ZA' '15ZB'
#  '15ZV' '16XD' '16YA' '16ZA' '16ZB' '16ZT' '16ZV' '17XD' '17YA' '17ZA'
#  '17ZB' '17ZV' '18ZA' '18ZB' '19ZA' '20XD' '20YA' '20ZA' '21XD' '21YA'
#  '21ZA' '22XD' '22ZA' '22ZG' '23XD' '23YA' '23ZA' '23ZG' '23ZH' '24ZA'
#  '24ZG' '24ZH' '25ZD' '25ZG' '25ZH' '26WW' '26ZA' '26ZG' '26ZH' '27ZA'
#  '27ZG' '27ZH' '28ZA' '28ZG' '28ZH' '29WW' '29ZB' '29ZG' '29ZH' '30YE'
#  '30ZA' '30ZB' '30ZG' '30ZH' '31XN' '31YE' '31ZB' '31ZG' '31ZH' '32YE'
#  '32ZB' '32ZH' '33YE' '33ZH' '34YE' '34ZH' '35YE' '35ZB' '35ZH' '36XG'
#  '36YE' '36ZB' '36ZH' '37XG' '37YE' '37ZB' '38YE' '38ZB' '38ZC' '38ZH'
#  '38ZV' '39YE' '39ZC' '39ZH' '39ZV' '40ZC' '40ZH' '40ZV' '41ZC' '41ZH'
#  '41ZV' '42ZC' '42ZH' '42ZV' '43ZA' '43ZC' '43ZV' '44ZA' '44ZC' '44ZV'
#  '45ZA' '45ZC' '45ZV' '46ZA' '46ZC' '46ZV' '47ZA' '47ZC' '47ZV' '48ZA'
#  '48ZT' '49XN' '49ZA' '50ZA' '50ZF' '50ZT' '51ZD' '52XJ' '56ZD' '57ZD'
#  '58ZD' '58ZY' '59ZD' '59ZY' '60ZY' '61XU' '61ZY' '62XU' '62ZY' '63XU'
#  '63ZI' '63ZY' '64XU' '64ZI' '64ZY' '65ZY' '66XU' '66ZI' '66ZY' '67ZI'
#  '67ZY' '68XU' '68ZY' '69XU' '69ZI' '69ZY' '70XU' '70ZY' '71ZI' '71ZY'
#  '72ZI' '72ZY' '73ZI' '73ZY' '74ZI' '74ZY' '75XY' '75ZI' '75ZY' '76XY'
#  '76ZY' '77XY' '77ZI' '77ZY' '78XY' '78ZI' '79XY' '80XY' '80ZI' '81XY'
#  '82XY' '83ZJ' '84ZJ' '85WX' '85ZJ' '86WX' '86ZJ' '87WX' '88WX' '88ZJ'
#  '89WX' '89ZJ' '90ZJ' '91WX' '91ZJ' '92WX' '93WX' '93ZF' '94WW' '94WX'
#  '94XA' '94ZF' '95WW' '95XA' '95ZF' '96XA' '96ZF' '97ZF' '97ZH' '98ZF'
#  '98ZH' '99ZF' '99ZH' 'BNL1' 'BNL8' 'BRY2' 'DPV1' 'DWZ3' 'DWZ8' 'DXD8'
#  'DXH6' 'EEI7' 'EKT4' 'FSG1' 'FSS3' 'FTC3' 'FTO5' 'FTY5']
#
# Valores da coluna SELB presentes apenas em um dos arquivos:
# Apenas em file1: ['02KD' '10BU' '10PN' ... 'YP75' 'ZG77' 'ZIF6']
# Apenas em file2: ['10YE' '11YE' '12XF' '12YE' '13XB' '13XF' '13YE' '14XF' '14XG' '14XN'
#  '14YA' '14YE' '14ZA' '15XF' '15XG' '15XN' '15YA' '15YE' '16XA' '16XF'
#  '16XN' '16YE' '17XA' '17XF' '17XG' '17XN' '17YE' '18XA' '18XD' '18XF'
#  '18XG' '18XN' '18XX' '18YA' '18YE' '18ZT' '19XA' '19XD' '19XF' '19XG'
#  '19XN' '19XX' '19YA' '19YE' '19ZT' '20XA' '20XF' '20XG' '20XN' '20XX'
#  '20YE' '21XA' '21XF' '21XG' '21XX' '21YE' '21ZT' '22XF' '22XG' '22XN'
#  '22XX' '22YA' '22YE' '23XA' '23XG' '23XN' '23XX' '23YE' '24XA' '24XN'
#  '24XX' '24YA' '24YE' '25WW' '25XG' '25XN' '25XX' '25YA' '25YE' '25ZA'
#  '26XG' '26XN' '26XX' '26YA' '26YE' '27WW' '27XG' '27XN' '27XX' '27YA'
#  '27YE' '28WW' '28XG' '28XN' '28YA' '28YE' '29XG' '29XN' '29YA' '29YE'
#  '30WW' '30XF' '30XG' '30XN' '30XS' '30YA' '30YD' '31WW' '31XF' '31XG'
#  '31XS' '31YA' '31YD' '32WW' '32XF' '32XG' '32XN' '32XS' '32YA' '32YD'
#  '33WW' '33XF' '33XG' '33XS' '33YA' '33YD' '33ZB' '34WW' '34XB' '34XS'
#  '34YA' '34YD' '34ZB' '35WW' '35XF' '35XS' '35YA' '35YD' '36WW' '36XF'
#  '36XS' '36XZ' '36YA' '36YD' '37WW' '37XF' '37XS' '37YA' '37YD' '37ZH'
#  '38WW' '38XF' '38XF ' '38XS' '38YA' '38YD' '39WW' '39XS' '39YA' '39YD'
#  '40WW' '40XF' '40YA' '40YD' '40ZI' '41WW' '41XF' '41YA' '41YD' '41ZI'
#  '42WW' '42XF' '42YA' '42YD' '42ZI' '43WW' '43XF' '43YA' '43YD' '43ZI'
#  '44WW' '44XF' '44YA' '44YD' '44ZI' '45XF' '45YA' '45YD' '45ZI' '46XF'
#  '46YA' '46YD' '46ZI' '47XF' '47YA' '47YD' '47ZI' '48XF' '48XX' '48YA'
#  '48YD' '48ZI' '49XF' '49YA' '49YD' '49ZI' '50XX' '50YA' '50ZI' '51WZ'
#  '51XY' '51XZ' '51ZC' '51ZE' '52WZ' '52XY' '52XZ' '52ZC' '52ZE' '53WZ'
#  '53XY' '53XZ' '53ZC' '53ZE' '53ZF' '54WZ' '54XY' '54XZ' '54ZC' '54ZE'
#  '54ZF' '55XC' '55XJ' '55XY' '55XZ' '55ZC' '55ZE' '55ZF' '56XY' '56XZ'
#  '56ZC' '56ZF' '57XC' '57XY' '57XZ' '57ZC' '57ZE' '57ZF' '58XC' '58XY'
#  '58ZC' '58ZE' '58ZF' '59XC' '59XY' '59ZC' '59ZE' '59ZF' '60XC' '60XY'
#  '60ZE' '60ZF' '61XC' '61XO' '61XY' '61ZB' '61ZE' '61ZF' '62XC' '62XO'
#  '62XY' '62ZB' '62ZE' '62ZF' '63XC' '63XO' '63XY' '63ZB' '63ZE' '63ZF'
#  '64XC' '64XO' '64XY' '64ZB' '64ZE' '64ZF' '65XC' '65XO' '65XU' '65XY'
#  '65ZB' '65ZE' '65ZF' '65ZI' '66 XV' '66XC' '66XO' '66XY' '66ZB' '66ZE'
#  '66ZF' '67XC' '67XO' '67XU' '67XY' '67ZB' '67ZE' '67ZF' '68XC' '68XO'
#  '68XY' '68ZB' '68ZE' '68ZF' '68ZI' '69XC' '69XO' '69XV' '69XY' '69ZB'
#  '69ZE' '69ZF' '70XC' '70XO' '70XV' '70XY' '70ZB' '70ZF' '71XC' '71XY'
#  '71YD' '71ZF' '72XC' '72XV ' '72XY' '72YD' '72ZF' '73XC' '73XV' '73XY'
#  '73YD' '74XC' '74XY' '74YD' '75XC' '75XJ' '75YD' '76WZ' '76XC' '76XJ'
#  '76YD' '76ZI' '77WZ' '77XC' '77XJ' '77YD' '78WZ' '78XC' '78XJ' '78YD'
#  '79WZ' '79XC' '79XJ' '79YD' '80WZ' '80XC' '80XJ' '80YD' '81WZ' '81XC'
#  '81XJ' '82WZ' '82XC' '82XJ' '82ZJ' '83WZ' '83XC' '83XJ' '83XY' '84WZ'
#  '84XC' '84XJ' '85WZ' '86XJ' '87XJ' '87ZJ' '88XJ' '88XZ' '89XJ' '89XZ'
#  '90XE' '90XJ' '91XJ' '91XZ' '91YD' '92XJ' '92XZ' '92YD' '93XJ' '93XZ'
#  '93YD' '94XJ' '94XZ' '94YD' '95XJ' '95XZ' '95YD' '96XJ' '96XZ' '96YD'
#  '96ZH' '97XJ' '97YD' '98XJ' '98YD' '99XJ' '99XZ' '99YD' '9WX' 'DPP9'
#  'DQL1' 'DQL6' 'DRU6' 'FAN1' 'FAN6' 'FBC2' 'FCH3' 'FSD3' 'FSE4' 'FSO4'
#  'FSQ6' 'FSZ5' 'FTA1' 'FTB7' 'FTK6' 'FTM3' 'FTV7' 'FTW3' 'FTZ6']
